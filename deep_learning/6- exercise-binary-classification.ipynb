# %% [markdown]
# **This notebook is an exercise in the [Intro to Deep Learning](https://www.kaggle.com/learn/intro-to-deep-learning) course.  You can reference the tutorial at [this link](https://www.kaggle.com/ryanholbrook/binary-classification).**
#
# ---

# %% [markdown]
# # Introduction #
#
# In this exercise, you'll build a model to predict hotel cancellations with a binary classifier.

# %%
# Setup plotting
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('animation', html='html5')

# Setup feedback system
from learntools.core import binder
binder.bind(globals())
from learntools.deep_learning_intro.ex6 import *

# %% [markdown]
# First, load the *Hotel Cancellations* dataset.

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer

hotel = pd.read_csv('../input/dl-course-data/hotel.csv')

X = hotel.copy()
y = X.pop('is_canceled')

X['arrival_date_month'] = \
    X['arrival_date_month'].map(
        {'January':1, 'February': 2, 'March':3,
         'April':4, 'May':5, 'June':6, 'July':7,
         'August':8, 'September':9, 'October':10,
         'November':11, 'December':12}
    )

features_num = [
    "lead_time", "arrival_date_week_number",
    "arrival_date_day_of_month", "stays_in_weekend_nights",
    "stays_in_week_nights", "adults", "children", "babies",
    "is_repeated_guest", "previous_cancellations",
    "previous_bookings_not_canceled", "required_car_parking_spaces",
    "total_of_special_requests", "adr",
]
features_cat = [
    "hotel", "arrival_date_month", "meal",
    "market_segment", "distribution_channel",
    "reserved_room_type", "deposit_type", "customer_type",
]

transformer_num = make_pipeline(
    SimpleImputer(strategy="constant"), # there are a few missing values
    StandardScaler(),
)
transformer_cat = make_pipeline(
    SimpleImputer(strategy="constant", fill_value="NA"),
    OneHotEncoder(handle_unknown='ignore'),
)

preprocessor = make_column_transformer(
    (transformer_num, features_num),
    (transformer_cat, features_cat),
)

# stratify - make sure classes are evenlly represented across splits
X_train, X_valid, y_train, y_valid = \
    train_test_split(X, y, stratify=y, train_size=0.75)

X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)

input_shape = [X_train.shape[1]]

# %% [markdown]
# # 1) Define Model #
#
# The model we'll use this time will have both batch normalization and dropout layers. To ease reading we've broken the diagram into blocks, but you can define it layer by layer as usual.
#
# Define a model with an architecture given by this diagram:
#
# <figure style="padding: 1em;">
# <img src="https://i.imgur.com/V04o59Z.png" width="400" alt="Diagram of network architecture: BatchNorm, Dense, BatchNorm, Dropout, Dense, BatchNorm, Dropout, Dense.">
# <figcaption style="textalign: center; font-style: italic"><center>Diagram of a binary classifier.</center></figcaption>
# </figure>

# %%
from tensorflow import keras
from tensorflow.keras import layers

# YOUR CODE HERE: define the model given in the diagram
model = keras.Sequential([
    layers.BatchNormalization(input_shape=input_shape),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(1, activation='sigmoid'),
])

# Check your answer
q_1.check()
# Out:
# Correct

# %% [markdown]
# # 2) Add Optimizer, Loss, and Metric #
#
# Now compile the model with the Adam optimizer and binary versions of the cross-entropy loss and accuracy metric.

# %%
# YOUR CODE HERE
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['binary_accuracy'],
)

# Check your answer
q_2.check()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
#q_2.hint()
#q_2.solution()

# %% [markdown]
# Finally, run this cell to train the model and view the learning curves. It may run for around 60 to 70 epochs, which could take a minute or two.

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=5,
    min_delta=0.001,
    restore_best_weights=True,
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=200,
    callbacks=[early_stopping],
)

history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot(title="Cross-entropy")
history_df.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot(title="Accuracy")
# Out:
# Epoch 1/200
# 175/175 [==============================] - 3s 8ms/step - loss: 0.5391 - binary_accuracy: 0.7433 - val_loss: 0.4326 - val_binary_accuracy: 0.7901
# Epoch 2/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.4270 - binary_accuracy: 0.7987 - val_loss: 0.3986 - val_binary_accuracy: 0.8111
# Epoch 3/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.4122 - binary_accuracy: 0.8079 - val_loss: 0.3897 - val_binary_accuracy: 0.8195
# Epoch 4/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.4041 - binary_accuracy: 0.8112 - val_loss: 0.3859 - val_binary_accuracy: 0.8192
# Epoch 5/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.4012 - binary_accuracy: 0.8130 - val_loss: 0.3822 - val_binary_accuracy: 0.8220
# Epoch 6/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.3925 - binary_accuracy: 0.8165 - val_loss: 0.3784 - val_binary_accuracy: 0.8241
# Epoch 7/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.3922 - binary_accuracy: 0.8169 - val_loss: 0.3772 - val_binary_accuracy: 0.8252
# Epoch 8/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.3864 - binary_accuracy: 0.8213 - val_loss: 0.3762 - val_binary_accuracy: 0.8280
# Epoch 9/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.3834 - binary_accuracy: 0.8204 - val_loss: 0.3734 - val_binary_accuracy: 0.8311
# Epoch 10/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.3774 - binary_accuracy: 0.8244 - val_loss: 0.3724 - val_binary_accuracy: 0.8304
# Epoch 11/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.3781 - binary_accuracy: 0.8249 - val_loss: 0.3741 - val_binary_accuracy: 0.8287
# Epoch 12/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.3733 - binary_accuracy: 0.8250 - val_loss: 0.3687 - val_binary_accuracy: 0.8321
# Epoch 13/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3714 - binary_accuracy: 0.8282 - val_loss: 0.3658 - val_binary_accuracy: 0.8316
# Epoch 14/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.3699 - binary_accuracy: 0.8288 - val_loss: 0.3619 - val_binary_accuracy: 0.8334
# Epoch 15/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.3682 - binary_accuracy: 0.8298 - val_loss: 0.3652 - val_binary_accuracy: 0.8319
# Epoch 16/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.3680 - binary_accuracy: 0.8282 - val_loss: 0.3613 - val_binary_accuracy: 0.8340
# Epoch 17/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.3644 - binary_accuracy: 0.8321 - val_loss: 0.3588 - val_binary_accuracy: 0.8357
# Epoch 18/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.3618 - binary_accuracy: 0.8327 - val_loss: 0.3573 - val_binary_accuracy: 0.8367
# Epoch 19/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.3660 - binary_accuracy: 0.8303 - val_loss: 0.3570 - val_binary_accuracy: 0.8374
# Epoch 20/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.3566 - binary_accuracy: 0.8361 - val_loss: 0.3555 - val_binary_accuracy: 0.8369
# Epoch 21/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.3563 - binary_accuracy: 0.8350 - val_loss: 0.3550 - val_binary_accuracy: 0.8370
# Epoch 22/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.3570 - binary_accuracy: 0.8328 - val_loss: 0.3561 - val_binary_accuracy: 0.8368
# Epoch 23/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.3536 - binary_accuracy: 0.8383 - val_loss: 0.3551 - val_binary_accuracy: 0.8341
# Epoch 24/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.3509 - binary_accuracy: 0.8378 - val_loss: 0.3524 - val_binary_accuracy: 0.8388
# Epoch 25/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.3551 - binary_accuracy: 0.8362 - val_loss: 0.3505 - val_binary_accuracy: 0.8388
# Epoch 26/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.3541 - binary_accuracy: 0.8356 - val_loss: 0.3534 - val_binary_accuracy: 0.8371
# Epoch 27/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3518 - binary_accuracy: 0.8361 - val_loss: 0.3524 - val_binary_accuracy: 0.8380
# Epoch 28/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3536 - binary_accuracy: 0.8352 - val_loss: 0.3496 - val_binary_accuracy: 0.8397
# Epoch 29/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.3474 - binary_accuracy: 0.8413 - val_loss: 0.3500 - val_binary_accuracy: 0.8385
# Epoch 30/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.3515 - binary_accuracy: 0.8375 - val_loss: 0.3501 - val_binary_accuracy: 0.8403
# <AxesSubplot:title={'center':'Accuracy'}>

# %%
history_df.head()
# Out:
#        loss  binary_accuracy  val_loss  val_binary_accuracy
# 0  0.484560         0.771504  0.432604             0.790137
# 1  0.423026         0.800641  0.398589             0.811110
# 2  0.410460         0.808079  0.389740             0.819452
# 3  0.403636         0.810424  0.385856             0.819217
# 4  0.398811         0.814378  0.382244             0.821965

# %% [markdown]
# # 3) Train and Evaluate #
#
#
# What do you think about the learning curves? Does it look like the model underfit or overfit? Was the cross-entropy loss a good stand-in for accuracy?

# %%
# The training look good

# %%
# View the solution (Run this cell to receive credit!)
q_3.check()
# Out:
# Correct:
#
# Though we can see the training loss continuing to fall, the early stopping callback prevented any overfitting. Moreover, the accuracy rose at the same rate as the cross-entropy fell, so it appears that minimizing cross-entropy was a good stand-in. All in all, it looks like this training was a success!

# %% [markdown]
# # Conclusion #
#
# Congratulations! You've completed Kaggle's *Introduction to Deep Learning* course!
#
# With your new skills you're ready to take on more advanced applications like computer vision and sentiment classification. What would you like to do next?
#
# Why not try one of our *Getting Started* competitions?
#
# - Classify images with TPUs in [**Petals to the Metal**](https://www.kaggle.com/c/tpu-getting-started)
# - Create art with GANs in [**I'm Something of a Painter Myself**](https://www.kaggle.com/c/gan-getting-started)
# - Classify Tweets in [**Real or Not? NLP with Disaster Tweets**](https://www.kaggle.com/c/nlp-getting-started)
# - Detect contradiction and entailment in [**Contradictory, My Dear Watson**](https://www.kaggle.com/c/contradictory-my-dear-watson)
#
# Until next time, Kagglers!

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [Learn Discussion forum](https://www.kaggle.com/learn-forum/191966) to chat with other Learners.*
